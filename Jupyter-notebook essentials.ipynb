# %% [markdown]
# # Keyboard shortcuts

# %% [markdown]
# esc- command mode

# %% [markdown]
# enter-again back to edit mode

# %% [markdown]
# in command mode you can lot of operations:
# a:create cell above
# b: create cell below
# arrow :to go above or below cells
# shift arrows: to select multiple cells
# dd:delete cell
# m:markdown
# y:code mode
# shift +enter:execute cell
# select cells then shift+m:to merge cells
# control+shift+minus:split a cell at certain point(be in that point first)
# tab :auto complete
# shift+tab inside a function:details of that method /function

# %% [markdown]
# # Command line

# %%
#just include ! before executing

# %%
# !pwd
# Out:
# /Users/akshaysubramanyaaithal

# %%
# !ls
# Out:
# Applications                      anaconda3
# Desktop                           api2
# Documents                         bashrc.save
# Downloads                         checkpoints
# Jupyter-notebook essentials.ipynb checkpoints.json
# Library                           fff.py
# Movies                            flagged
# Music                             install.sh
# Pictures                          learning
# Postman                           modelapi2.py
# Public                            nltk_data
# airflow                           pyspark

# %%
#!pip install numpy

# %% [markdown]
# # Display rows and columns how much u want

# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/akshaysubramanyaaithal/Desktop/Sentiment Analysis/Extracting Aspects from questions/question_reponse_reason.csv")

# %%
df
# Out:
#      Unnamed: 0                                           question  \
# 0             0  Please rate the level of advice and communicat...
# 1             1  How likely is it that you would recommend [Reg...
# 2             2  Compared to other lenders, do you feel New Ame...
# 3             3  Would you be interested in one or more of the ...
# 4             4  The closing fees and interest rate were as pro...
# ..          ...                                                ...
# 106         106  Please rate the level of knowledge you receive...
# 107         107  Regarding your experience with your Loan Proce...
# 108         108  Based on your experience, how do you feel abou...
# 109         109  How would you rate your overall experience wit...
# 110         110       Overall, how satisfied are you with Caliber?
#
#                                                 aspect
# 0    {"aspect":"Communication experience","reason":...
# ...

# %%
#as we can see its not displaying all rows, you can control that but be careful while doing for larger dataframes

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#      Unnamed: 0                                           question  \
# 0             0  Please rate the level of advice and communicat...
# 1             1  How likely is it that you would recommend [Reg...
# 2             2  Compared to other lenders, do you feel New Ame...
# 3             3  Would you be interested in one or more of the ...
# 4             4  The closing fees and interest rate were as pro...
# 5             5  Relative to [RegionName], did the closing date...
# 6             6  Overall, how satisfied are you with your exper...
# 7             7  <p>Would\nyou refer Movement based largely on ...
# 8             8  How would you rate the level of communication ...
# 9             9  Is there anything that stands out about your e...
# 10           10  Did Impact Lending help your decision to work ...
# 11           11  We love to see our happy homeowners. If you'd ...
# 12           12  Based on your previous experience with Go Mort...
# ...

# %%
#again set it back to normal, or else it will behave like that only for all dataframes.
pd.set_option('display.max_rows', 10)

# %%
df
# Out:
#      Unnamed: 0                                           question  \
# 0             0  Please rate the level of advice and communicat...
# 1             1  How likely is it that you would recommend [Reg...
# 2             2  Compared to other lenders, do you feel New Ame...
# 3             3  Would you be interested in one or more of the ...
# 4             4  The closing fees and interest rate were as pro...
# ..          ...                                                ...
# 106         106  Please rate the level of knowledge you receive...
# 107         107  Regarding your experience with your Loan Proce...
# 108         108  Based on your experience, how do you feel abou...
# 109         109  How would you rate your overall experience wit...
# 110         110       Overall, how satisfied are you with Caliber?
#
#                                                 aspect
# 0    {"aspect":"Communication experience","reason":...
# ...

# %%
#same for coumns

# %%
pd.set_option('display.max_columns', None)

# %%
#setting back to normal or any other number
pd.set_option('display.max_columns', 10)

# %%
df
# Out:
#      Unnamed: 0                                           question  \
# 0             0  Please rate the level of advice and communicat...
# 1             1  How likely is it that you would recommend [Reg...
# 2             2  Compared to other lenders, do you feel New Ame...
# 3             3  Would you be interested in one or more of the ...
# 4             4  The closing fees and interest rate were as pro...
# ..          ...                                                ...
# 106         106  Please rate the level of knowledge you receive...
# 107         107  Regarding your experience with your Loan Proce...
# 108         108  Based on your experience, how do you feel abou...
# 109         109  How would you rate your overall experience wit...
# 110         110       Overall, how satisfied are you with Caliber?
#
#                                                 aspect
# 0    {"aspect":"Communication experience","reason":...
# ...

# %% [markdown]
# # supressing warning

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

subset = df[df['A'] > 1]
subset['B'] = subset['B'] + 1
# Out:
# /var/folders/wm/d3d528hx6274zl9wjcbrj1700000gn/T/ipykernel_58163/2930817428.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['B'] = subset['B'] + 1

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

subset = df[df['A'] > 1]
subset['B'] = subset['B'] + 1

# %% [markdown]
# # Printing oututs

# %%
a=2
b=3
df.describe()
a
b
# Out:
# 3

# %% [markdown]
# #### if u see above only the last cell output is printed, if u want all outputs run below cell

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
a=2
b=3
df.describe()
a
b
# Out:
#          A    B
# count  3.0  3.0
# mean   2.0  5.0
# std    1.0  1.0
# min    1.0  4.0
# 25%    1.5  4.5
# 50%    2.0  5.0
# 75%    2.5  5.5
# max    3.0  6.0
# 2
# 3

# %% [markdown]
# #### variable called Out will save all cell outputs in notebook.

# %%
Out
# Out:
# {16:      Unnamed: 0                                           question  \
#  0             0  Please rate the level of advice and communicat...
#  1             1  How likely is it that you would recommend [Reg...
#  2             2  Compared to other lenders, do you feel New Ame...
#  3             3  Would you be interested in one or more of the ...
#  4             4  The closing fees and interest rate were as pro...
#  ..          ...                                                ...
#  106         106  Please rate the level of knowledge you receive...
#  107         107  Regarding your experience with your Loan Proce...
#  108         108  Based on your experience, how do you feel abou...
#  109         109  How would you rate your overall experience wit...
#  110         110       Overall, how satisfied are you with Caliber?
#
#                                                  aspect
#  0    {"aspect":"Communication experience","reason":...
# ...

# %%
#these are all the outputs

# %%
a=3
a
# Out:
# 3

# %% [markdown]
# if u want output of certain cell use like list indexing

# %%
Out[45]
# Out:
# 3

# %%
#since no ouptut in that cell
Out[44]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 Out[44]
#
# KeyError: 44

# %%
#use semicolon at the end of the code if u are getting unnecessary information 
#like how you get when you do visualization inmatplotlib
import matplotlib.pyplot as plt
plt.plot(range(3),range(3));

# %% [markdown]
# # Magic commands

# %% [raw]
# %:for single line
# %%:for multi line,this should be in first line

# %%
#this gives the time to run the single line
# %time sum(range(100))
# Out:
# CPU times: user 6 µs, sys: 5 µs, total: 11 µs
# Wall time: 16.9 µs
# 4950

# %%
#%%time gives the time to run that full cell provided it is in first cell only.

# %%
# %%time
sum=0
for i in range(100):
    sum=sum+i
print(sum)
# Out:
# 4950
# CPU times: user 437 µs, sys: 138 µs, total: 575 µs
# Wall time: 572 µs

# %% [markdown]
# #### to write into a file:

# %%
# %%writefile example.txt
#
# Hello, this is the first line of the file.
# And this is the second line.
# Out:
# Writing example.txt

# %%
# %%writefile my_sum.py
def fun(x,y):
    return x+y
print(fun(2,3))
# Out:
# Writing my_sum.py

# %%
#if u want to run a .py file in notebook do this:

# %run my_sum.py
# Out:
# 5

# %% [markdown]
# #### run html code

# %%
# %%html
# <div style="color: red; font-size: 20px;">Hello, world!</div>
# Out:
# <div style="color: red; font-size: 20px;">Hello, world!</div>

# %%
#to run javascript : %%javascript , and in next line codes

# %% [markdown]
# #### to embed latex in notebook

# %%
# %%latex
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1{c} \, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1{c} \, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}
# Out:
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1{c} \, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1{c} \, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %% [markdown]
# # widgets

# %%
#use widgets to embed different widgets into the notebooks 
#like if u want to make your visualization dynamic

# %% [raw]
# https://ipywidgets.readthedocs.io/en/latest/index.html

# %% [markdown]
# # extentions

# %%
# !pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
# !jupyter nbextensions_configurator enable --user
